# %% [markdown]
# # HelloWorld
# ## 1. 笔记本用法
# > 右键创建笔记本
#
# ![img](img/image.png)

# %% [markdown]
# ## 运行命令

# %%
# !python -V
# Out:
# Python 3.13.5

# %%
# !pip -V
# Out:
# pip 25.3 from D:\Programs\python313\Lib\site-packages\pip (python 3.13)

# %% [markdown]
# ## 运行代码

# %%
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [4,2,7,3,6,7]

plt.plot(x,y)
plt.show()

# %%
print("2342")
# Out:
# 2342
